# %% [markdown]
# # # Data_analysis of NYPD dataset

# %% [markdown]
# Python imports are essential for successfully organising your code.
# We import the required libraries to help in data extraction, cleaning and plotting graphs.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from math import radians, sin, cos, acos
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Use pandas to import/read the input file.

# %%
data = pd.read_csv(r"C:\Users\MaraligaVenkateshAsh\Downloads\NYPD_Arrests_Data__Historic_.csv")

# %% [markdown]
# Check whether there are any NaN values.

# %%
data.isnull().sum()
# Out:
# ARREST_KEY               0
# ARREST_DATE              0
# PD_CD                  220
# PD_DESC               8870
# KY_CD                 8870
# OFNS_DESC             8870
# LAW_CODE               196
# LAW_CAT_CD           16103
# ARREST_BORO              8
# ARREST_PRECINCT          0
# JURISDICTION_CODE       10
# AGE_GROUP               17
# PERP_SEX                 0
# PERP_RACE                0
# X_COORD_CD               1
# Y_COORD_CD               1
# Latitude                 1
# Longitude                1
# dtype: int64

# %% [markdown]
# Create a copy of the data frame rather than changing the original data frame. Work with the copy to avoid unnecessary changes to the original file.
# We will have an original file to compare the altered version with this.

# %%
data1 = data.copy()

# %%
data1
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                               PD_DESC  \
# 0         173130602  12/31/2017  566.0                 MARIJUANA, POSSESSION
# 1         173114463  12/31/2017  478.0       THEFT OF SERVICES, UNCLASSIFIED
# 2         173113513  12/31/2017  849.0  NY STATE LAWS,UNCLASSIFIED VIOLATION
# 3         173113423  12/31/2017  101.0                             ASSAULT 3
# 4         173113421  12/31/2017  101.0                             ASSAULT 3
# ...             ...         ...    ...                                   ...
# 4798334   173142136  01/01/2018  639.0               AGGRAVATED HARASSMENT 2
# 4798335   173135232  01/01/2018  109.0              ASSAULT 2,1,UNCLASSIFIED
# 4798336   173134328  01/01/2018  397.0       ROBBERY,UNCLASSIFIED,OPEN AREAS
# 4798337   173134322  01/01/2018  922.0        TRAFFIC,UNCLASSIFIED MISDEMEAN
# 4798338   173130592  01/01/2018  109.0              ASSAULT 2,1,UNCLASSIFIED
#
#          KY_CD                                    OFNS_DESC    LAW_CODE  \
# 0        678.0                      MISCELLANEOUS PENAL LAW  PL 2210500
# 1        343.0              OTHER OFFENSES RELATED TO THEFT  PL 1651503
# 2        677.0                             OTHER STATE LAWS  LOC000000V
# 3        344.0                 ASSAULT 3 & RELATED OFFENSES  PL 1200001
# 4        344.0                 ASSAULT 3 & RELATED OFFENSES  PL 1200001
# ...        ...                                          ...         ...
# 4798334  361.0  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002
# 4798335  106.0                               FELONY ASSAULT  PL 1200502
# 4798336  105.0                                      ROBBERY  PL 1601503
# 4798337  348.0                     VEHICLE AND TRAFFIC LAWS  VTL0511001
# 4798338  106.0                               FELONY ASSAULT  PL 1200512
#
#         LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# 0                V           Q              105                0.0     25-44
# 1                M           Q              114                0.0     25-44
# 2                V           K               73                1.0     18-24
# 3                M           M               18                0.0     25-44
# 4                M           M               18                0.0     45-64
# ...            ...         ...              ...                ...       ...
# 4798334          M           B               41                0.0     25-44
# 4798335          F           B               44                0.0     25-44
# 4798336          F           M               10                0.0     45-64
# 4798337          M           M               30                0.0     25-44
# 4798338          F           K               70                0.0     45-64
#
#         PERP_SEX                 PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 0              M                     BLACK   1063056.0    207463.0  40.735772
# 1              M  ASIAN / PACIFIC ISLANDER   1009113.0    219613.0  40.769437
# 2              M                     BLACK   1010719.0    186857.0  40.679525
# 3              M                     WHITE    987831.0    217446.0  40.763523
# 4              M                     BLACK    987073.0    216078.0  40.759768
# ...          ...                       ...         ...         ...        ...
# 4798334        F            WHITE HISPANIC   1013086.0    236614.0  40.816088
# 4798335        M            BLACK HISPANIC   1007649.0    243339.0  40.834562
# 4798336        M                     BLACK    983620.0    208914.0  40.740105
# 4798337        M            BLACK HISPANIC    998981.0    242209.0  40.831479
# 4798338        M            BLACK HISPANIC    995824.0    170921.0  40.635816
#
#          Longitude
# 0       -73.715638
# 1       -73.910241
# 2       -73.904572
# 3       -73.987074
# 4       -73.989811
# ...            ...
# 4798334 -73.895824
# 4798335 -73.915443
# 4798336 -74.002275
# 4798337 -73.946770
# 4798338 -73.958301
#
# [4798339 rows x 18 columns]

# %% [markdown]
# The fillna() function substitutes a value in place of NaN values.

# %%
data1.fillna(0,inplace=True)

# %%
data1.isnull().sum()
# Out:
# ARREST_KEY           0
# ARREST_DATE          0
# PD_CD                0
# PD_DESC              0
# KY_CD                0
# OFNS_DESC            0
# LAW_CODE             0
# LAW_CAT_CD           0
# ARREST_BORO          0
# ARREST_PRECINCT      0
# JURISDICTION_CODE    0
# AGE_GROUP            0
# PERP_SEX             0
# PERP_RACE            0
# X_COORD_CD           0
# Y_COORD_CD           0
# Latitude             0
# Longitude            0
# dtype: int64

# %% [markdown]
# Use the panda's package to convert the string objects in the "ARREST_DATE" column to datetime objects.

# %%
 data1['ARREST_DATE'] =  pd.to_datetime(data1['ARREST_DATE'])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4798339 entries, 0 to 4798338
# Data columns (total 18 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ARREST_KEY         int64
#  1   ARREST_DATE        datetime64[ns]
#  2   PD_CD              float64
#  3   PD_DESC            object
#  4   KY_CD              float64
#  5   OFNS_DESC          object
#  6   LAW_CODE           object
#  7   LAW_CAT_CD         object
#  8   ARREST_BORO        object
#  9   ARREST_PRECINCT    int64
#  10  JURISDICTION_CODE  float64
#  11  AGE_GROUP          object
#  12  PERP_SEX           object
#  13  PERP_RACE          object
#  14  X_COORD_CD         float64
#  15  Y_COORD_CD         float64
#  16  Latitude           float64
#  17  Longitude          float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(8)
# memory usage: 659.0+ MB

# %% [markdown]
# For our project team, we need to analyze the data of 2006 and 2018, so we filter the 2006 and 2018 data using pandas.loc function.

# %%
dataFiltered = data1.loc[((data1['ARREST_DATE'] >= '2006-01-01') & (data1['ARREST_DATE'] < '2007-01-01') | (data1['ARREST_DATE'] >= '2018-01-01') & (data1['ARREST_DATE'] < '2019-01-01') )]

# %% [markdown]
# Check the length(No. of records) of the filtered data for the years 2006 and 2018.

# %%
len(dataFiltered)
# Out:
# 618707

# %% [markdown]
# Create "Year" and "Month" columns by extracting the values from the "ARREST_DATE" column.

# %%
dataFiltered['Year'] = pd.DatetimeIndex(dataFiltered['ARREST_DATE']).year
dataFiltered['Month'] = pd.DatetimeIndex(dataFiltered['ARREST_DATE']).month

# %% [markdown]
# Reset the index and drop the index column.Only remove the appropriate levels from the index for a Series with a MultiIndex. By default, all levels are removed. Reset the index in the new DataFrame without adding it as a column.

# %%
dataFiltered.reset_index(inplace=True)

# %%
dataFiltered.drop(['index'],axis=1,inplace=True)

# %%
dataFiltered
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 0         26043689  2006-12-31  793.0
# 1         26029858  2006-12-31  567.0
# 2         26029459  2006-12-31  759.0
# 3         26029450  2006-12-31  515.0
# 4         26018937  2006-12-31  203.0
# ...            ...         ...    ...
# 618702   173142136  2018-01-01  639.0
# 618703   173135232  2018-01-01  109.0
# 618704   173134328  2018-01-01  397.0
# 618705   173134322  2018-01-01  922.0
# 618706   173130592  2018-01-01  109.0
#
#                                          PD_DESC  KY_CD  \
# 0                           WEAPONS POSSESSION 3  118.0
# 1                    MARIJUANA, POSSESSION 4 & 5  235.0
# 2       PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4  359.0
# 3                    CONTROLLED SUBSTANCE,SALE 3  117.0
# 4                           TRESPASS 3, CRIMINAL  352.0
# ...                                          ...    ...
# 618702                   AGGRAVATED HARASSMENT 2  361.0
# 618703                  ASSAULT 2,1,UNCLASSIFIED  106.0
# 618704           ROBBERY,UNCLASSIFIED,OPEN AREAS  105.0
# 618705            TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 618706                  ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                                           OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                                 DANGEROUS WEAPONS  PL 2650205          F
# 1                                   DANGEROUS DRUGS  PL 2211500          M
# 2            OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 1950500          M
# 3                                   DANGEROUS DRUGS  PL 2203901          F
# 4                                 CRIMINAL TRESPASS  PL 140100F          M
# ...                                             ...         ...        ...
# 618702  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002          M
# 618703                               FELONY ASSAULT  PL 1200502          F
# 618704                                      ROBBERY  PL 1601503          F
# 618705                     VEHICLE AND TRAFFIC LAWS  VTL0511001          M
# 618706                               FELONY ASSAULT  PL 1200512          F
#
#        ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0                B               44                0.0     18-24        M
# 1                S              123                0.0     18-24        M
# 2                B               40                2.0     18-24        M
# 3                B               47                0.0     25-44        M
# 4                Q              101                0.0     18-24        M
# ...            ...              ...                ...       ...      ...
# 618702           B               41                0.0     25-44        F
# 618703           B               44                0.0     25-44        M
# 618704           M               10                0.0     45-64        M
# 618705           M               30                0.0     25-44        M
# 618706           K               70                0.0     45-64        M
#
#              PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  \
# 0       BLACK HISPANIC   1008669.0    246692.0  40.843762 -73.911745  2006
# 1                WHITE    934968.0    136245.0  40.540508 -74.177311  2006
# 2                BLACK   1005947.0    235372.0  40.812699 -73.921620  2006
# 3                BLACK   1025612.0    268457.0  40.903437 -73.850375  2006
# 4                BLACK   1043516.0    157081.0  40.597637 -73.786589  2006
# ...                ...         ...         ...        ...        ...   ...
# 618702  WHITE HISPANIC   1013086.0    236614.0  40.816088 -73.895824  2018
# 618703  BLACK HISPANIC   1007649.0    243339.0  40.834562 -73.915443  2018
# 618704           BLACK    983620.0    208914.0  40.740105 -74.002275  2018
# 618705  BLACK HISPANIC    998981.0    242209.0  40.831479 -73.946770  2018
# 618706  BLACK HISPANIC    995824.0    170921.0  40.635816 -73.958301  2018
#
#         Month
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
# ...       ...
# 618702      1
# 618703      1
# 618704      1
# 618705      1
# 618706      1
#
# [618707 rows x 20 columns]

# %%
dataFiltered[dataFiltered['Year']==2006]['AGE_GROUP'].value_counts()
# Out:
# 25-44      174717
# 18-24       98326
# 45-64       59310
# <18         37179
# 65+          2300
# 0              17
# 894             7
# 945             5
# UNKNOWN         5
# 935             5
# 932             3
# 895             3
# 943             3
# 944             2
# 920             2
# 912             2
# 951             2
# 929             2
# 947             2
# 938             2
# 952             2
# 928             2
# 921             2
# 931             2
# 352             1
# 708             1
# 948             1
# 194             1
# 316             1
# 816             1
# 939             1
# 237             1
# 949             1
# 933             1
# 922             1
# 740             1
# 956             1
# 339             1
# 946             1
# 940             1
# 309             1
# 959             1
# 941             1
# 927             1
# 910             1
# 446             1
# 942             1
# 330             1
# 320             1
# 955             1
# 723             1
# 934             1
# 930             1
# 965             1
# 323             1
# 338             1
# Name: AGE_GROUP, dtype: int64

# %% [markdown]
# Creating sample dataframe from filtered data to analyse the data.
# Once the algorithm is developed test it on this sample and later implement on the whole.
# The code written to test the sample is removed after testing and only the main code for the whole set will be made available in the document.

# %%
DataFilteredSample  = dataFiltered.sample(n=75,random_state=2181998)

# %%
DataFilteredSample
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                               PD_DESC  \
# 505199   183463636  2018-06-04  205.0                  TRESPASS 2, CRIMINAL
# 41450     25336228  2006-11-16  969.0       TRAFFIC,UNCLASSIFIED INFRACTION
# 331955    10334553  2006-02-08  205.0                  TRESPASS 2, CRIMINAL
# 21374     25682711  2006-12-07  569.0                 MARIJUANA, SALE 4 & 5
# 560025   176022954  2018-03-18  101.0                             ASSAULT 3
# ...            ...         ...    ...                                   ...
# 613386   173403526  2018-01-09  101.0                             ASSAULT 3
# 184129    16942077  2006-07-01  849.0  NY STATE LAWS,UNCLASSIFIED VIOLATION
# 325810    10388835  2006-02-15  205.0                  TRESPASS 2, CRIMINAL
# 590775   174444845  2018-02-06  918.0                      RECKLESS DRIVING
# 6557      25905078  2006-12-22  614.0                      LOITERING,SCHOOL
#
#         KY_CD                     OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 505199  352.0             CRIMINAL TRESPASS  PL 1401500          M
# 41450   881.0      OTHER TRAFFIC INFRACTION  VTL051101A          M
# 331955  352.0             CRIMINAL TRESPASS  PL 1401500          M
# 21374   235.0               DANGEROUS DRUGS  PL 2214000          M
# 560025  344.0  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# ...       ...                           ...         ...        ...
# 613386  344.0  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# 184129  677.0              OTHER STATE LAWS  LOC000000V          V
# 325810  352.0             CRIMINAL TRESPASS  PL 1401500          M
# 590775  348.0      VEHICLE AND TRAFFIC LAWS  VTL1212000          M
# 6557    672.0                     LOITERING  PL 2403505          V
#
#        ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 505199           Q              109                0.0     25-44        M
# 41450            M               34                0.0     25-44        M
# 331955           K               81                0.0     45-64        M
# 21374            K               61                0.0     25-44        M
# 560025           K               68                0.0     45-64        M
# ...            ...              ...                ...       ...      ...
# 613386           B               44                0.0     25-44        M
# 184129           K               79                1.0     45-64        M
# 325810           M               10                0.0     18-24        M
# 590775           K               63                0.0     18-24        M
# 6557             K               67                0.0     18-24        M
#
#              PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  \
# 505199         UNKNOWN   1026496.0    221242.0  40.773842 -73.847474  2018
# 41450   WHITE HISPANIC   1006670.0    254235.0  40.864471 -73.918945  2006
# 331955           BLACK   1003562.0    186782.0  40.679337 -73.930375  2006
# 21374            WHITE    999929.0    151922.0  40.583661 -73.943554  2006
# 560025           WHITE    979227.0    170035.0  40.633390 -74.018099  2018
# ...                ...         ...         ...        ...        ...   ...
# 613386           BLACK   1006195.0    240321.0  40.826282 -73.920708  2018
# 184129           BLACK    998241.0    187165.0  40.680399 -73.949558  2006
# 325810           BLACK    985591.0    215684.0  40.758687 -73.995161  2006
# 590775           WHITE   1004620.0    163933.0  40.616619 -73.926630  2018
# 6557             BLACK   1005937.0    175620.0  40.648695 -73.921848  2006
#
#         Month
# 505199      6
# 41450      11
# 331955      2
# 21374      12
# 560025      3
# ...       ...
# 613386      1
# 184129      7
# 325810      2
# 590775      2
# 6557       12
#
# [75 rows x 20 columns]

# %% [markdown]
# ## a)Analysis of the NYPD arrest data for the years 2006 and 2018 for each of the 5 boroughs(using the ARREST_BORO attribute)

# %% [markdown]
# First, let us compare the crime rate for the given years.
# The first graph depicts the number of crimes committed during the given year.

# %%
dataFiltered['Year'].value_counts().plot(kind="bar", title = "Total Crime Events by Year")
# Out:
# <AxesSubplot:title={'center':'Total Crime Events by Year'}>

# %%
dataFiltered[dataFiltered['Year']==2006]
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 0         26043689  2006-12-31  793.0
# 1         26029858  2006-12-31  567.0
# 2         26029459  2006-12-31  759.0
# 3         26029450  2006-12-31  515.0
# 4         26018937  2006-12-31  203.0
# ...            ...         ...    ...
# 371929     9929890  2006-01-01  101.0
# 371930     9929888  2006-01-01  625.0
# 371931     9929860  2006-01-01  748.0
# 371932     9929834  2006-01-01  750.0
# 371933     9929812  2006-01-01  969.0
#
#                                          PD_DESC  KY_CD  \
# 0                           WEAPONS POSSESSION 3  118.0
# 1                    MARIJUANA, POSSESSION 4 & 5  235.0
# 2       PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4  359.0
# 3                    CONTROLLED SUBSTANCE,SALE 3  117.0
# 4                           TRESPASS 3, CRIMINAL  352.0
# ...                                          ...    ...
# 371929                                 ASSAULT 3  344.0
# 371930     DISORDERLY CONDUCT SUBD 1,2,3,4,5,6,7  572.0
# 371931                         CONTEMPT,CRIMINAL  359.0
# 371932                          RESISTING ARREST  359.0
# 371933           TRAFFIC,UNCLASSIFIED INFRACTION  881.0
#
#                                      OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                            DANGEROUS WEAPONS  PL 2650205          F
# 1                              DANGEROUS DRUGS  PL 2211500          M
# 2       OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 1950500          M
# 3                              DANGEROUS DRUGS  PL 2203901          F
# 4                            CRIMINAL TRESPASS  PL 140100F          M
# ...                                        ...         ...        ...
# 371929            ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
# 371930                      DISORDERLY CONDUCT  PL 2402001          V
# 371931  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2155003          M
# 371932  OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 2053000          M
# 371933                OTHER TRAFFIC INFRACTION  VTL051101A          M
#
#        ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0                B               44                0.0     18-24        M
# 1                S              123                0.0     18-24        M
# 2                B               40                2.0     18-24        M
# 3                B               47                0.0     25-44        M
# 4                Q              101                0.0     18-24        M
# ...            ...              ...                ...       ...      ...
# 371929           B               44                0.0     18-24        F
# 371930           B               52                0.0     25-44        M
# 371931           B               41                0.0     25-44        M
# 371932           B               47                0.0     18-24        M
# 371933           B               52                0.0     18-24        F
#
#              PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  \
# 0       BLACK HISPANIC   1008669.0    246692.0  40.843762 -73.911745  2006
# 1                WHITE    934968.0    136245.0  40.540508 -74.177311  2006
# 2                BLACK   1005947.0    235372.0  40.812699 -73.921620  2006
# 3                BLACK   1025612.0    268457.0  40.903437 -73.850375  2006
# 4                BLACK   1043516.0    157081.0  40.597637 -73.786589  2006
# ...                ...         ...         ...        ...        ...   ...
# 371929           BLACK   1007418.0    243859.0  40.835990 -73.916276  2006
# 371930  WHITE HISPANIC   1013169.0    255021.0  40.866609 -73.895445  2006
# 371931           BLACK   1015845.0    236500.0  40.815765 -73.885857  2006
# 371932           BLACK   1020534.0    256806.0  40.871481 -73.868807  2006
# 371933           BLACK   1017440.0    256046.0  40.869407 -73.879998  2006
#
#         Month
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
# ...       ...
# 371929      1
# 371930      1
# 371931      1
# 371932      1
# 371933      1
#
# [371934 rows x 20 columns]

# %%
dataFiltered[dataFiltered['Year']==2006].groupby('Month').size().plot(kind = 'bar', title ='Total Crime Events by Month in 2006', color = '#C0392B',rot=0)
plt.savefig('total_crimes_per_month_2006.png', format='png')

# %%
dataFiltered[dataFiltered['Year']==2018].groupby('Month').size().plot(kind = 'bar', title ='Total Crime Events by Month in 2018', color = '#C0392B',rot=0)
plt.savefig('total_crimes_per_month_2018.png', format='png')

# %% [markdown]
# From the above graphs,the number of crimes are very high in March,May and January whereas October, November, and December appear to be safer.

# %%
dataFiltered
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 0         26043689  2006-12-31  793.0
# 1         26029858  2006-12-31  567.0
# 2         26029459  2006-12-31  759.0
# 3         26029450  2006-12-31  515.0
# 4         26018937  2006-12-31  203.0
# ...            ...         ...    ...
# 618702   173142136  2018-01-01  639.0
# 618703   173135232  2018-01-01  109.0
# 618704   173134328  2018-01-01  397.0
# 618705   173134322  2018-01-01  922.0
# 618706   173130592  2018-01-01  109.0
#
#                                          PD_DESC  KY_CD  \
# 0                           WEAPONS POSSESSION 3  118.0
# 1                    MARIJUANA, POSSESSION 4 & 5  235.0
# 2       PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4  359.0
# 3                    CONTROLLED SUBSTANCE,SALE 3  117.0
# 4                           TRESPASS 3, CRIMINAL  352.0
# ...                                          ...    ...
# 618702                   AGGRAVATED HARASSMENT 2  361.0
# 618703                  ASSAULT 2,1,UNCLASSIFIED  106.0
# 618704           ROBBERY,UNCLASSIFIED,OPEN AREAS  105.0
# 618705            TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 618706                  ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                                           OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                                 DANGEROUS WEAPONS  PL 2650205          F
# 1                                   DANGEROUS DRUGS  PL 2211500          M
# 2            OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 1950500          M
# 3                                   DANGEROUS DRUGS  PL 2203901          F
# 4                                 CRIMINAL TRESPASS  PL 140100F          M
# ...                                             ...         ...        ...
# 618702  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002          M
# 618703                               FELONY ASSAULT  PL 1200502          F
# 618704                                      ROBBERY  PL 1601503          F
# 618705                     VEHICLE AND TRAFFIC LAWS  VTL0511001          M
# 618706                               FELONY ASSAULT  PL 1200512          F
#
#        ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0                B               44                0.0     18-24        M
# 1                S              123                0.0     18-24        M
# 2                B               40                2.0     18-24        M
# 3                B               47                0.0     25-44        M
# 4                Q              101                0.0     18-24        M
# ...            ...              ...                ...       ...      ...
# 618702           B               41                0.0     25-44        F
# 618703           B               44                0.0     25-44        M
# 618704           M               10                0.0     45-64        M
# 618705           M               30                0.0     25-44        M
# 618706           K               70                0.0     45-64        M
#
#              PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  \
# 0       BLACK HISPANIC   1008669.0    246692.0  40.843762 -73.911745  2006
# 1                WHITE    934968.0    136245.0  40.540508 -74.177311  2006
# 2                BLACK   1005947.0    235372.0  40.812699 -73.921620  2006
# 3                BLACK   1025612.0    268457.0  40.903437 -73.850375  2006
# 4                BLACK   1043516.0    157081.0  40.597637 -73.786589  2006
# ...                ...         ...         ...        ...        ...   ...
# 618702  WHITE HISPANIC   1013086.0    236614.0  40.816088 -73.895824  2018
# 618703  BLACK HISPANIC   1007649.0    243339.0  40.834562 -73.915443  2018
# 618704           BLACK    983620.0    208914.0  40.740105 -74.002275  2018
# 618705  BLACK HISPANIC    998981.0    242209.0  40.831479 -73.946770  2018
# 618706  BLACK HISPANIC    995824.0    170921.0  40.635816 -73.958301  2018
#
#         Month
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
# ...       ...
# 618702      1
# 618703      1
# 618704      1
# 618705      1
# 618706      1
#
# [618707 rows x 20 columns]

# %%
dataFiltered['Year'].value_counts()
# Out:
# 2006    371934
# 2018    246773
# Name: Year, dtype: int64

# %% [markdown]
# Compare the number of arrests for misdemeanor (M) and violation (V) for given years and save it as a png file.

# %%
a = sns.catplot(x="ARREST_BORO", hue='LAW_CAT_CD', col="Year",data=dataFiltered[(dataFiltered["LAW_CAT_CD"] == 'M') | (dataFiltered["LAW_CAT_CD"] == 'V') ], kind="count",height=7, aspect=.8)
a.set_xlabels('NY city Boroughs', fontsize=12)
a.set_ylabels('misdemeanor(M) and violation(V)', fontsize=12)
a.savefig('output_Law_CAT_CD.png', dpi=300)

# %% [markdown]
# Count the total number of crimes in each borough during the years 2006 and 2018 and save it as png file.

# %%
dataFiltered[dataFiltered['Year']==2006]['ARREST_BORO'].value_counts().sort_values().plot(kind="barh", color = '#1ABC9C', title = 'Total of Crime Events by Borough in year 2006')
plt.savefig('total_crimes in 2006.png', format='png')

# %%
dataFiltered[dataFiltered['Year']==2018]['ARREST_BORO'].value_counts().sort_values().plot(kind="barh", color = '#1ABC9C', title = 'Total of Crime Events by Borough in year 2018')
plt.savefig('total_crimes in 2018.png', format='png')

# %%
dataFiltered['ARREST_BORO'].value_counts().sort_values()
# Out:
# S     22830
# Q    120160
# B    139341
# M    164938
# K    171438
# Name: ARREST_BORO, dtype: int64

# %% [markdown]
# According to this visualization, K has the overall highest numeventsber of crime.

# %% [markdown]
# compare the number of arrests based on gender for each year and save it as png file.

# %%
a=sns.catplot(x="ARREST_BORO",hue='PERP_SEX',col="Year",data=dataFiltered[(dataFiltered["LAW_CAT_CD"] == 'M') | (dataFiltered["LAW_CAT_CD"] == 'V') ], kind="count",height=7, aspect=.8)
a.set_xlabels('NY city Boroughs', fontsize=12)
a.set_ylabels('Male and Female', fontsize=12)
a.savefig('output_Male and Female.png', dpi=300)

# %% [markdown]
# We can observe that the distribution of crimes done by males and females during both the years 2006 and 2018 show a similar proportion.

# %% [markdown]
# Following draw plot based on the race to find any pattern or changes happened between the time 2006 and 2018.

# %%
a=sns.catplot(x="ARREST_BORO",hue='PERP_RACE',col="Year",data=dataFiltered[(dataFiltered["LAW_CAT_CD"] == 'M') | (dataFiltered["LAW_CAT_CD"] == 'V') ], kind="count",height=7, aspect=.8)
a.set_xlabels('NY city Boroughs', fontsize=12)
a.set_ylabels('Total number of crimes', fontsize=12)
a.savefig('output_PERP_RACE.png', dpi=720)

# %% [markdown]
# We can see the ratio of crimes by the different races has seen no change in any of the boroughs when we compare the 2006 and 2018 with black people hvaing major contribution in every borugh except in the Staten Land.

# %%
ax = sns.catplot(x="ARREST_BORO",data=dataFiltered[(dataFiltered["LAW_CAT_CD"] == 'M') | (dataFiltered["LAW_CAT_CD"] == 'V') ], kind="count",height=7, aspect=.8)
ax.savefig('output_Total.png', dpi=720)

# %% [markdown]
# ## b)Identify the age group Which has the most number of arrests in M or V category for each borough and compare the number of arrests of different age groups each year and save the png file

# %%
#Check the age distribution by grouping the similar values.
dataFiltered['AGE_GROUP'].value_counts()
# Out:
# 25-44      303864
# 18-24      151090
# 45-64      109232
# <18         49119
# 65+          5300
# 0              17
# 894             7
# 945             5
# UNKNOWN         5
# 935             5
# 932             3
# 895             3
# 943             3
# 944             2
# 920             2
# 912             2
# 951             2
# 929             2
# 947             2
# 938             2
# 952             2
# 928             2
# 921             2
# 931             2
# 352             1
# 708             1
# 948             1
# 194             1
# 316             1
# 816             1
# 939             1
# 237             1
# 949             1
# 933             1
# 922             1
# 740             1
# 956             1
# 339             1
# 946             1
# 940             1
# 309             1
# 959             1
# 941             1
# 927             1
# 910             1
# 446             1
# 942             1
# 330             1
# 320             1
# 955             1
# 723             1
# 934             1
# 930             1
# 965             1
# 323             1
# 338             1
# Name: AGE_GROUP, dtype: int64

# %% [markdown]
# Because the age groups have distinct values, we must substitute 65+  if the age is more than 65,so we are using apply lambda function to do the entire process in a single code

# %%
dataFiltered['AGE_GROUP'] = dataFiltered['AGE_GROUP'].apply(lambda x:'65+' if len(str(x))==3 else x)

# %%
dataFiltered
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 0         26043689  2006-12-31  793.0
# 1         26029858  2006-12-31  567.0
# 2         26029459  2006-12-31  759.0
# 3         26029450  2006-12-31  515.0
# 4         26018937  2006-12-31  203.0
# ...            ...         ...    ...
# 618702   173142136  2018-01-01  639.0
# 618703   173135232  2018-01-01  109.0
# 618704   173134328  2018-01-01  397.0
# 618705   173134322  2018-01-01  922.0
# 618706   173130592  2018-01-01  109.0
#
#                                          PD_DESC  KY_CD  \
# 0                           WEAPONS POSSESSION 3  118.0
# 1                    MARIJUANA, POSSESSION 4 & 5  235.0
# 2       PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4  359.0
# 3                    CONTROLLED SUBSTANCE,SALE 3  117.0
# 4                           TRESPASS 3, CRIMINAL  352.0
# ...                                          ...    ...
# 618702                   AGGRAVATED HARASSMENT 2  361.0
# 618703                  ASSAULT 2,1,UNCLASSIFIED  106.0
# 618704           ROBBERY,UNCLASSIFIED,OPEN AREAS  105.0
# 618705            TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 618706                  ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                                           OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                                 DANGEROUS WEAPONS  PL 2650205          F
# 1                                   DANGEROUS DRUGS  PL 2211500          M
# 2            OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 1950500          M
# 3                                   DANGEROUS DRUGS  PL 2203901          F
# 4                                 CRIMINAL TRESPASS  PL 140100F          M
# ...                                             ...         ...        ...
# 618702  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002          M
# 618703                               FELONY ASSAULT  PL 1200502          F
# 618704                                      ROBBERY  PL 1601503          F
# 618705                     VEHICLE AND TRAFFIC LAWS  VTL0511001          M
# 618706                               FELONY ASSAULT  PL 1200512          F
#
#        ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 0                B               44                0.0     18-24        M
# 1                S              123                0.0     18-24        M
# 2                B               40                2.0     18-24        M
# 3                B               47                0.0     25-44        M
# 4                Q              101                0.0     18-24        M
# ...            ...              ...                ...       ...      ...
# 618702           B               41                0.0     25-44        F
# 618703           B               44                0.0     25-44        M
# 618704           M               10                0.0     45-64        M
# 618705           M               30                0.0     25-44        M
# 618706           K               70                0.0     45-64        M
#
#              PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  \
# 0       BLACK HISPANIC   1008669.0    246692.0  40.843762 -73.911745  2006
# 1                WHITE    934968.0    136245.0  40.540508 -74.177311  2006
# 2                BLACK   1005947.0    235372.0  40.812699 -73.921620  2006
# 3                BLACK   1025612.0    268457.0  40.903437 -73.850375  2006
# 4                BLACK   1043516.0    157081.0  40.597637 -73.786589  2006
# ...                ...         ...         ...        ...        ...   ...
# 618702  WHITE HISPANIC   1013086.0    236614.0  40.816088 -73.895824  2018
# 618703  BLACK HISPANIC   1007649.0    243339.0  40.834562 -73.915443  2018
# 618704           BLACK    983620.0    208914.0  40.740105 -74.002275  2018
# 618705  BLACK HISPANIC    998981.0    242209.0  40.831479 -73.946770  2018
# 618706  BLACK HISPANIC    995824.0    170921.0  40.635816 -73.958301  2018
#
#         Month
# 0          12
# 1          12
# 2          12
# 3          12
# 4          12
# ...       ...
# 618702      1
# 618703      1
# 618704      1
# 618705      1
# 618706      1
#
# [618707 rows x 20 columns]

# %%
dataFiltered['AGE_GROUP'].value_counts()
# Out:
# 25-44      303864
# 18-24      151090
# 45-64      109232
# 65+         54499
# 0              17
# UNKNOWN         5
# Name: AGE_GROUP, dtype: int64

# %%
ax = sns.catplot(x="AGE_GROUP", hue='LAW_CAT_CD', col="Year",data=dataFiltered[(dataFiltered["LAW_CAT_CD"] == 'M') | (dataFiltered["LAW_CAT_CD"] == 'V') ], kind="count",height=7, aspect=0.9)
ax.set_xlabels('Age Groups', fontsize=12)
ax.set_ylabels('misdemeanor(M) and violation(V)', fontsize=12)
ax.savefig('output_Age_groups.png', dpi=300)

# %% [markdown]
# Plot the graph concerning the misdemeanors(M) and violations(V) committed during 2006 and 2018 for various age groups.

# %% [markdown]
# from above graph,In 2006 and 2018, the age group 25-44 had the largest number of crimes.

# %%
ax= sns.catplot(x="ARREST_BORO", hue='LAW_CAT_CD', col="Year",data=dataFiltered[((dataFiltered["LAW_CAT_CD"] == 'M') | (dataFiltered["LAW_CAT_CD"] == 'V')) & (dataFiltered['AGE_GROUP']=='25-44')], kind="count",height=7, aspect=0.9)
ax.set_xlabels('Age_group of 25-44', fontsize=12)
ax.set_ylabels('misdemeanor(M) and violation(V)', fontsize=12)
ax.savefig('output_Age_groups_25-44.png', dpi=300)

# %% [markdown]
# ## c)Randomly pick a location (i.e., lat and long) for each Borough and compute the number of arrests in a radius of 3 miles from that location

# %% [markdown]
# The below function finds the distance in miles between the given longitudes and latitudes.

# %%
def distance(lat1,lon1,lat2,lon2):
    slat=radians(lat1)
    slon=radians(lon1)
    elat=radians(lat2)
    elon=radians(lon2)
    #The output c will be in kilometeres.
    c= 6371.01 * acos(sin(slat)*sin(elat) + cos(slat)*cos(elat)*cos(slon - elon))
    #now conver the c into miles and return the value.
    return c/1.60934

# %% [markdown]
# Now call the distance function to find the distance between the given coordinates and the longitudes and latitudes in the records.

# %%
a=[]
lat1=float(input("Starting latitude place_1: "))
lon1=float(input("Starting longitude place_1: "))
for i in range(0,len(dataFiltered)):
    a.append(distance(lat1,lon1,dataFiltered['Latitude'][i],dataFiltered['Longitude'][i]))
# Out:
# Starting latitude place_1: 40.84
# Starting longitude place_1: -73.911

# %%
len(a)
# Out:
# 618707

# %% [markdown]
# Add the new column "Distance in miles" with the distance between the given point and respective point.

# %%
dataFiltered['Distance in miles'] = a

# %%
dataFiltered
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 0         26043689  2006-12-31  793.0
# 1         26029858  2006-12-31  567.0
# 2         26029459  2006-12-31  759.0
# 3         26029450  2006-12-31  515.0
# 4         26018937  2006-12-31  203.0
# ...            ...         ...    ...
# 618702   173142136  2018-01-01  639.0
# 618703   173135232  2018-01-01  109.0
# 618704   173134328  2018-01-01  397.0
# 618705   173134322  2018-01-01  922.0
# 618706   173130592  2018-01-01  109.0
#
#                                          PD_DESC  KY_CD  \
# 0                           WEAPONS POSSESSION 3  118.0
# 1                    MARIJUANA, POSSESSION 4 & 5  235.0
# 2       PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4  359.0
# 3                    CONTROLLED SUBSTANCE,SALE 3  117.0
# 4                           TRESPASS 3, CRIMINAL  352.0
# ...                                          ...    ...
# 618702                   AGGRAVATED HARASSMENT 2  361.0
# 618703                  ASSAULT 2,1,UNCLASSIFIED  106.0
# 618704           ROBBERY,UNCLASSIFIED,OPEN AREAS  105.0
# 618705            TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 618706                  ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                                           OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                                 DANGEROUS WEAPONS  PL 2650205          F
# 1                                   DANGEROUS DRUGS  PL 2211500          M
# 2            OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 1950500          M
# 3                                   DANGEROUS DRUGS  PL 2203901          F
# 4                                 CRIMINAL TRESPASS  PL 140100F          M
# ...                                             ...         ...        ...
# 618702  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002          M
# 618703                               FELONY ASSAULT  PL 1200502          F
# 618704                                      ROBBERY  PL 1601503          F
# 618705                     VEHICLE AND TRAFFIC LAWS  VTL0511001          M
# 618706                               FELONY ASSAULT  PL 1200512          F
#
#        ARREST_BORO  ARREST_PRECINCT  ...  AGE_GROUP PERP_SEX       PERP_RACE  \
# 0                B               44  ...      18-24        M  BLACK HISPANIC
# 1                S              123  ...      18-24        M           WHITE
# 2                B               40  ...      18-24        M           BLACK
# 3                B               47  ...      25-44        M           BLACK
# 4                Q              101  ...      18-24        M           BLACK
# ...            ...              ...  ...        ...      ...             ...
# 618702           B               41  ...      25-44        F  WHITE HISPANIC
# 618703           B               44  ...      25-44        M  BLACK HISPANIC
# 618704           M               10  ...      45-64        M           BLACK
# 618705           M               30  ...      25-44        M  BLACK HISPANIC
# 618706           K               70  ...      45-64        M  BLACK HISPANIC
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  Month  \
# 0       1008669.0    246692.0  40.843762 -73.911745  2006     12
# 1        934968.0    136245.0  40.540508 -74.177311  2006     12
# 2       1005947.0    235372.0  40.812699 -73.921620  2006     12
# 3       1025612.0    268457.0  40.903437 -73.850375  2006     12
# 4       1043516.0    157081.0  40.597637 -73.786589  2006     12
# ...           ...         ...        ...        ...   ...    ...
# 618702  1013086.0    236614.0  40.816088 -73.895824  2018      1
# 618703  1007649.0    243339.0  40.834562 -73.915443  2018      1
# 618704   983620.0    208914.0  40.740105 -74.002275  2018      1
# 618705   998981.0    242209.0  40.831479 -73.946770  2018      1
# 618706   995824.0    170921.0  40.635816 -73.958301  2018      1
#
#         Distance in miles
# 0                0.262845
# 1               24.957089
# 2                1.966333
# 3                5.407828
# 4               17.968444
# ...                   ...
# 618702           1.832818
# 618703           0.441733
# 618704           8.392643
# 618705           1.960373
# 618706          14.323495
#
# [618707 rows x 21 columns]

# %% [markdown]
# Filter records from each borough that are in the range of 3 miles from the given location.

# %%
ARREST_BORO_Q = dataFiltered.loc[(dataFiltered['ARREST_BORO'] == 'Q') & (dataFiltered['Distance in miles'] <=3)]
ARREST_BORO_K = dataFiltered.loc[(dataFiltered['ARREST_BORO'] == 'K') & (dataFiltered['Distance in miles'] <=3)]
ARREST_BORO_B = dataFiltered.loc[(dataFiltered['ARREST_BORO'] == 'B') & (dataFiltered['Distance in miles'] <=3)]
ARREST_BORO_M = dataFiltered.loc[(dataFiltered['ARREST_BORO'] == 'M') & (dataFiltered['Distance in miles'] <=3)]
ARREST_BORO_S = dataFiltered.loc[(dataFiltered['ARREST_BORO'] == 'S') & (dataFiltered['Distance in miles'] <=3)]

# %%
print("the number of arrest in ARREST_BORO_Q is",len(ARREST_BORO_Q))
print("the number of arrest in ARREST_BORO_K is",len(ARREST_BORO_K))
print("the number of arrest in ARREST_BORO_B is",len(ARREST_BORO_B))
print("the number of arrest in ARREST_BORO_M is",len(ARREST_BORO_M))
print("the number of arrest in ARREST_BORO_S is",len(ARREST_BORO_S))
# Out:
# the number of arrest in ARREST_BORO_Q is 1
# the number of arrest in ARREST_BORO_K is 0
# the number of arrest in ARREST_BORO_B is 112269
# the number of arrest in ARREST_BORO_M is 45198
# the number of arrest in ARREST_BORO_S is 0

# %% [markdown]
# Create a new data frame with the filtered records from each borough in the range of 3 miles from the given location to plot the markers on the map.

# %%
dataFilteredLocation = dataFiltered.loc[(dataFiltered['Distance in miles'] <=3)]

# %%
dataFilteredLocation
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD  \
# 0         26043689  2006-12-31  793.0
# 2         26029459  2006-12-31  759.0
# 5         26029472  2006-12-31  113.0
# 6         26029474  2006-12-31  782.0
# 7         26029478  2006-12-31  205.0
# ...            ...         ...    ...
# 618693   173148933  2018-01-01  105.0
# 618699   173142231  2018-01-01  193.0
# 618702   173142136  2018-01-01  639.0
# 618703   173135232  2018-01-01  109.0
# 618705   173134322  2018-01-01  922.0
#
#                                          PD_DESC  KY_CD  \
# 0                           WEAPONS POSSESSION 3  118.0
# 2       PUBLIC ADMINISTATION,UNCLASS MISDEMEAN 4  359.0
# 5                          MENACING,UNCLASSIFIED  344.0
# 6                       WEAPONS, POSSESSION, ETC  236.0
# 7                           TRESPASS 2, CRIMINAL  352.0
# ...                                          ...    ...
# 618693                         STRANGULATION 1ST  106.0
# 618699                  CUSTODIAL INTERFERENCE 1  124.0
# 618702                   AGGRAVATED HARASSMENT 2  361.0
# 618703                  ASSAULT 2,1,UNCLASSIFIED  106.0
# 618705            TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
#
#                                           OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                                 DANGEROUS WEAPONS  PL 2650205          F
# 2            OFFENSES AGAINST PUBLIC ADMINISTRATION  PL 1950500          M
# 5                      ASSAULT 3 & RELATED OFFENSES  PL 1201401          M
# 6                                 DANGEROUS WEAPONS  PL 2650101          M
# 7                                 CRIMINAL TRESPASS  PL 1401500          M
# ...                                             ...         ...        ...
# 618693                               FELONY ASSAULT  PL 1211200          F
# 618699                KIDNAPPING & RELATED OFFENSES  PL 1355002          F
# 618702  OFF. AGNST PUB ORD SENSBLTY & RGHTS TO PRIV  PL 2403002          M
# 618703                               FELONY ASSAULT  PL 1200502          F
# 618705                     VEHICLE AND TRAFFIC LAWS  VTL0511001          M
#
#        ARREST_BORO  ARREST_PRECINCT  ...  AGE_GROUP PERP_SEX       PERP_RACE  \
# 0                B               44  ...      18-24        M  BLACK HISPANIC
# 2                B               40  ...      18-24        M           BLACK
# 5                B               52  ...      18-24        M  WHITE HISPANIC
# 6                B               48  ...      25-44        M           BLACK
# 7                B               42  ...      45-64        F  WHITE HISPANIC
# ...            ...              ...  ...        ...      ...             ...
# 618693           B               52  ...      25-44        M           BLACK
# 618699           M               33  ...      25-44        M  WHITE HISPANIC
# 618702           B               41  ...      25-44        F  WHITE HISPANIC
# 618703           B               44  ...      25-44        M  BLACK HISPANIC
# 618705           M               30  ...      25-44        M  BLACK HISPANIC
#
#        X_COORD_CD  Y_COORD_CD   Latitude  Longitude  Year  Month  \
# 0       1008669.0    246692.0  40.843762 -73.911745  2006     12
# 2       1005947.0    235372.0  40.812699 -73.921620  2006     12
# 5       1009868.0    253126.0  40.861418 -73.907387  2006     12
# 6       1012615.0    246810.0  40.844074 -73.897483  2006     12
# 7       1009945.0    244103.0  40.836653 -73.907143  2006     12
# ...           ...         ...        ...        ...   ...    ...
# 618693  1017440.0    256046.0  40.869407 -73.879998  2018      1
# 618699  1002912.0    247450.0  40.845857 -73.932550  2018      1
# 618702  1013086.0    236614.0  40.816088 -73.895824  2018      1
# 618703  1007649.0    243339.0  40.834562 -73.915443  2018      1
# 618705   998981.0    242209.0  40.831479 -73.946770  2018      1
#
#         Distance in miles
# 0                0.262845
# 2                1.966333
# 5                1.491859
# 6                0.760562
# 7                0.306820
# ...                   ...
# 618693           2.598733
# 618699           1.196906
# 618702           1.832818
# 618703           0.441733
# 618705           1.960373
#
# [157468 rows x 21 columns]

# %%
len(dataFilteredLocation)
# Out:
# 157468

# %% [markdown]
# Using a map, plot all of the sites that are less than or equal to 3 miles with the help of folium.

# %%
m = folium.Map(location=[dataFilteredLocation.iloc[0]['Latitude'], dataFilteredLocation.iloc[0]['Longitude']])
for i  in range(0,100):
    folium.Marker(
    location=[dataFilteredLocation.iloc[i]['Latitude'], dataFilteredLocation.iloc[i]['Longitude']],
   ).add_to(m)

# %% [markdown]
# We're only charting 100 points; if we have more than 10,000 places within 3 miles of each other, it will show up, but it will be difficult to visualize.

# %% [markdown]
# The below map consists of the arrests happened in the 3 mile radius from the given coordinates in the years 2006 and 2018.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_9dcb585a90914b9e8ca5b924a2ce166c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9dcb585a90914b9e8ca5b924a2ce166c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9dcb585a90914b9e8ca5b924a2ce166c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_9dcb585a90914b9e8ca5b924a2ce166c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.84376218800003%2C%20-73.91174515299997%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...
